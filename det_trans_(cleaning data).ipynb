# %%
import pandas as pd

# %%
df_excel = pd.read_excel('DETAIL TRANSAKSI.xlsx')

# %%
df_excel.head()
# Out:
#   REPORTED_DATE TERM PAYMENT KOMISI-    DEPARTMENT    COMPLETED INSTALL  \
# 0    2023-01-17          JAN      ST   SA SURABAYA  2022-12-26 00:00:00
# 1    2023-01-17          JAN      ST     SA CIDENG  2022-12-01 00:00:00
# 2    2023-01-17          JAN      ST  SA FATMAWATI  2022-12-01 00:00:00
# 3    2023-01-17          JAN      ST     SA CIDENG  2022-12-03 00:00:00
# 4    2023-01-17          JAN      ST     SA CIDENG  2022-12-05 00:00:00
#
#    CUST_ACCT ADD_INT_PRODUCT SALES_CODE POSITION AGENCY           DIVISION  \
# 0          1           PRD 1       KSF1      VMS   AG 1  DIRECT SALES AREA
# 1          2           PRD 1       KCO5      VMS   AG 2  DIRECT SALES AREA
# 2          3           PRD 1       LOV2      VMS   AG 1  DIRECT SALES AREA
# 3          4           PRD 1       KCP1      VMS   AG 2  DIRECT SALES AREA
# 4          5           PRD 1       JPI6      VMS   AG 3  DIRECT SALES AREA
#
#    DEPARTMENT 2      CITY PAYMENT_STATUS  NILAI REVENUE PRODUCT CHURN_DATE  \
# ...

# %%
df_excel.rename(columns={'COMPLETED INSTALL':'TGL_COMPLETED'},inplace=True)

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11080 entries, 0 to 11079
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REPORTED_DATE          11080 non-null  datetime64[ns]
#  1   TERM PAYMENT           11080 non-null  object
#  2   KOMISI-                11080 non-null  object
#  3   DEPARTMENT             11080 non-null  object
#  4   TGL_COMPLETED          11080 non-null  object
#  5   CUST_ACCT              11080 non-null  int64
#  6   ADD_INT_PRODUCT        11077 non-null  object
#  7   SALES_CODE             11080 non-null  object
#  8   POSITION               11080 non-null  object
#  9   AGENCY                 11080 non-null  object
#  10  DIVISION               11080 non-null  object
#  11  DEPARTMENT 2           11080 non-null  object
#  12  CITY                   11080 non-null  object
#  13  PAYMENT_STATUS         11080 non-null  object
# ...

# %%
df_new = df_excel

# %%
df_new.isnull().any()
# Out:
# REPORTED_DATE            False
# TERM PAYMENT             False
# KOMISI-                  False
# DEPARTMENT               False
# TGL_COMPLETED            False
# CUST_ACCT                False
# ADD_INT_PRODUCT           True
# SALES_CODE               False
# POSITION                 False
# AGENCY                   False
# DIVISION                 False
# DEPARTMENT 2             False
# CITY                     False
# PAYMENT_STATUS           False
# NILAI REVENUE PRODUCT    False
# CHURN_DATE                True
# COMMISSION_GROSS          True
# dtype: bool

# %%
df_new.isnull().sum()
# Out:
# REPORTED_DATE                0
# TERM PAYMENT                 0
# KOMISI-                      0
# DEPARTMENT                   0
# TGL_COMPLETED                0
# CUST_ACCT                    0
# ADD_INT_PRODUCT              3
# SALES_CODE                   0
# POSITION                     0
# AGENCY                       0
# DIVISION                     0
# DEPARTMENT 2                 0
# CITY                         0
# PAYMENT_STATUS               0
# NILAI REVENUE PRODUCT        0
# CHURN_DATE               10237
# COMMISSION_GROSS             6
# dtype: int64

# %%
df_new.describe()
# Out:
#                        REPORTED_DATE     CUST_ACCT  NILAI REVENUE PRODUCT  \
# count                          11080  11080.000000           1.108000e+04
# mean   2023-04-05 02:14:46.353790720   5540.500000           3.008321e+05
# min              2022-07-27 00:00:00      1.000000           1.627500e+05
# 25%              2023-01-17 00:00:00   2770.750000           2.380000e+05
# 50%              2023-04-10 00:00:00   5540.500000           2.750000e+05
# 75%              2023-07-17 00:00:00   8310.250000           2.950000e+05
# max              2023-12-13 00:00:00  11080.000000           3.106500e+06
# std                              NaN   3198.664826           1.518326e+05
#
#                           CHURN_DATE  COMMISSION_GROSS
# count                            843      1.107400e+04
# mean   2023-04-09 01:44:11.957295360      2.148223e+05
# min              2022-07-07 00:00:00      0.000000e+00
# 25%              2022-12-29 00:00:00      1.320900e+05
# ...

# %%
df_new['TGL_COMPLETED']=pd.to_datetime(df_new['TGL_COMPLETED'])

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11080 entries, 0 to 11079
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REPORTED_DATE          11080 non-null  datetime64[ns]
#  1   TERM PAYMENT           11080 non-null  object
#  2   KOMISI-                11080 non-null  object
#  3   DEPARTMENT             11080 non-null  object
#  4   TGL_COMPLETED          11080 non-null  datetime64[ns]
#  5   CUST_ACCT              11080 non-null  int64
#  6   ADD_INT_PRODUCT        11077 non-null  object
#  7   SALES_CODE             11080 non-null  object
#  8   POSITION               11080 non-null  object
#  9   AGENCY                 11080 non-null  object
#  10  DIVISION               11080 non-null  object
#  11  DEPARTMENT 2           11080 non-null  object
#  12  CITY                   11080 non-null  object
#  13  PAYMENT_STATUS         11080 non-null  object
# ...

# %%
df_new.drop(['DEPARTMENT 2'],axis=1,inplace=True)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11080 entries, 0 to 11079
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REPORTED_DATE          11080 non-null  datetime64[ns]
#  1   TERM PAYMENT           11080 non-null  object
#  2   KOMISI-                11080 non-null  object
#  3   DEPARTMENT             11080 non-null  object
#  4   TGL_COMPLETED          11080 non-null  datetime64[ns]
#  5   CUST_ACCT              11080 non-null  int64
#  6   ADD_INT_PRODUCT        11077 non-null  object
#  7   SALES_CODE             11080 non-null  object
#  8   POSITION               11080 non-null  object
#  9   AGENCY                 11080 non-null  object
#  10  DIVISION               11080 non-null  object
#  11  CITY                   11080 non-null  object
#  12  PAYMENT_STATUS         11080 non-null  object
#  13  NILAI REVENUE PRODUCT  11080 non-null  int64
# ...

# %%
df_new.rename(columns={'KOMISI-':'KOMISI'},inplace=True)

# %%
df_new['ADD_INT_PRODUCT'].fillna('-',inplace=True)
# Out:
# <ipython-input-18-df3e532a7bb4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new['ADD_INT_PRODUCT'].fillna('-',inplace=True)

# %%
df_new['CHURN_DATE'].fillna(0,inplace=True)
# Out:
# <ipython-input-19-c6a63313c8b6>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new['CHURN_DATE'].fillna(0,inplace=True)
# <ipython-input-19-c6a63313c8b6>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df_new['CHURN_DATE'].fillna(0,inplace=True)

# %%
df_new.isnull().sum()
# Out:
# REPORTED_DATE            0
# TERM PAYMENT             0
# KOMISI                   0
# DEPARTMENT               0
# TGL_COMPLETED            0
# CUST_ACCT                0
# ADD_INT_PRODUCT          0
# SALES_CODE               0
# POSITION                 0
# AGENCY                   0
# DIVISION                 0
# CITY                     0
# PAYMENT_STATUS           0
# NILAI REVENUE PRODUCT    0
# CHURN_DATE               0
# COMMISSION_GROSS         0
# dtype: int64

# %%
df_new['COMMISSION_GROSS'].fillna(0,inplace=True)
# Out:
# <ipython-input-21-37096d41e451>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new['COMMISSION_GROSS'].fillna(0,inplace=True)

# %%
df_new['TGL_COMPLETED'].unique()
# Out:
# <DatetimeArray>
# ['2022-12-26 00:00:00', '2022-12-01 00:00:00', '2022-12-03 00:00:00',
#  '2022-12-05 00:00:00', '2022-12-19 00:00:00', '2022-12-07 00:00:00',
#  '2022-12-20 00:00:00', '2022-12-09 00:00:00', '2022-12-08 00:00:00',
#  '2022-12-14 00:00:00',
#  ...
#  '2023-11-23 00:00:00', '2023-11-11 00:00:00', '2023-11-09 00:00:00',
#  '2023-11-14 00:00:00', '2023-11-29 00:00:00', '2023-11-02 00:00:00',
#  '2023-11-21 00:00:00', '2023-11-04 00:00:00', '2023-11-17 00:00:00',
#  '2023-11-10 00:00:00']
# Length: 550, dtype: datetime64[ns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11080 entries, 0 to 11079
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REPORTED_DATE          11080 non-null  datetime64[ns]
#  1   TERM PAYMENT           11080 non-null  object
#  2   KOMISI                 11080 non-null  object
#  3   DEPARTMENT             11080 non-null  object
#  4   TGL_COMPLETED          11080 non-null  datetime64[ns]
#  5   CUST_ACCT              11080 non-null  int64
#  6   ADD_INT_PRODUCT        11080 non-null  object
#  7   SALES_CODE             11080 non-null  object
#  8   POSITION               11080 non-null  object
#  9   AGENCY                 11080 non-null  object
#  10  DIVISION               11080 non-null  object
#  11  CITY                   11080 non-null  object
#  12  PAYMENT_STATUS         11080 non-null  object
#  13  NILAI REVENUE PRODUCT  11080 non-null  int64
# ...

# %%
df_new['CHURN_DATE'].unique()
# Out:
# array([0, Timestamp('2022-10-23 00:00:00'),
#        Timestamp('2022-12-31 00:00:00'), Timestamp('2022-11-30 00:00:00'),
#        Timestamp('2022-12-07 00:00:00'), Timestamp('2023-01-07 00:00:00'),
#        Timestamp('2022-12-15 00:00:00'), Timestamp('2022-10-25 00:00:00'),
#        Timestamp('2022-11-29 00:00:00'), Timestamp('2022-11-15 00:00:00'),
#        Timestamp('2022-12-29 00:00:00'), Timestamp('2022-10-15 00:00:00'),
#        Timestamp('2022-08-22 00:00:00'), Timestamp('2022-07-15 00:00:00'),
#        Timestamp('2022-11-07 00:00:00'), Timestamp('2022-11-24 00:00:00'),
#        Timestamp('2022-12-27 00:00:00'), Timestamp('2022-08-15 00:00:00'),
#        Timestamp('2022-11-23 00:00:00'), Timestamp('2022-12-30 00:00:00'),
#        Timestamp('2022-10-26 00:00:00'), Timestamp('2022-07-07 00:00:00'),
#        Timestamp('2022-09-15 00:00:00'), Timestamp('2022-07-27 00:00:00'),
#        Timestamp('2022-10-29 00:00:00'), Timestamp('2022-09-27 00:00:00'),
# ...

# %%
#df.replace({2: np.nan, 7: np.nan}, inplace=True)
df_new['CHURN_DATE'].replace({0:''},inplace=True)

# %%
df_new['CHURN_DATE'].unique()
# Out:
# array(['', Timestamp('2022-10-23 00:00:00'),
#        Timestamp('2022-12-31 00:00:00'), Timestamp('2022-11-30 00:00:00'),
#        Timestamp('2022-12-07 00:00:00'), Timestamp('2023-01-07 00:00:00'),
#        Timestamp('2022-12-15 00:00:00'), Timestamp('2022-10-25 00:00:00'),
#        Timestamp('2022-11-29 00:00:00'), Timestamp('2022-11-15 00:00:00'),
#        Timestamp('2022-12-29 00:00:00'), Timestamp('2022-10-15 00:00:00'),
#        Timestamp('2022-08-22 00:00:00'), Timestamp('2022-07-15 00:00:00'),
#        Timestamp('2022-11-07 00:00:00'), Timestamp('2022-11-24 00:00:00'),
#        Timestamp('2022-12-27 00:00:00'), Timestamp('2022-08-15 00:00:00'),
#        Timestamp('2022-11-23 00:00:00'), Timestamp('2022-12-30 00:00:00'),
#        Timestamp('2022-10-26 00:00:00'), Timestamp('2022-07-07 00:00:00'),
#        Timestamp('2022-09-15 00:00:00'), Timestamp('2022-07-27 00:00:00'),
#        Timestamp('2022-10-29 00:00:00'), Timestamp('2022-09-27 00:00:00'),
# ...

# %%
df_new['CHURN_DATE']=pd.to_datetime(df_new['CHURN_DATE'])

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11080 entries, 0 to 11079
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REPORTED_DATE          11080 non-null  datetime64[ns]
#  1   TERM PAYMENT           11080 non-null  object
#  2   KOMISI                 11080 non-null  object
#  3   DEPARTMENT             11080 non-null  object
#  4   TGL_COMPLETED          11080 non-null  datetime64[ns]
#  5   CUST_ACCT              11080 non-null  int64
#  6   ADD_INT_PRODUCT        11080 non-null  object
#  7   SALES_CODE             11080 non-null  object
#  8   POSITION               11080 non-null  object
#  9   AGENCY                 11080 non-null  object
#  10  DIVISION               11080 non-null  object
#  11  CITY                   11080 non-null  object
#  12  PAYMENT_STATUS         11080 non-null  object
#  13  NILAI REVENUE PRODUCT  11080 non-null  int64
# ...

# %%
df_new.isnull().sum()
# Out:
# REPORTED_DATE                0
# TERM PAYMENT                 0
# KOMISI                       0
# DEPARTMENT                   0
# TGL_COMPLETED                0
# CUST_ACCT                    0
# ADD_INT_PRODUCT              0
# SALES_CODE                   0
# POSITION                     0
# AGENCY                       0
# DIVISION                     0
# CITY                         0
# PAYMENT_STATUS               0
# NILAI REVENUE PRODUCT        0
# CHURN_DATE               10237
# COMMISSION_GROSS             0
# dtype: int64

# %%
df_new.to_excel("cleansing_det_trans.xlsx", index=False)
